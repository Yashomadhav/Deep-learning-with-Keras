# %% [markdown]
# # Assignment 1 - Deep Learning With Keras - 40%
#
# **IMPORTANT NOTE**: By default, this notebook is set to a CPU runtime, to help prevent you getting locked out of Google Colab. When training your models, you will need to switch to a GPU runtime, otherwise the training will take a very long time.
#
# **Deadline**: 21 Mar 2023, 23:59
#
# **Submission Requirements**: You should submit your Colab Notebook, with all the outputs printed, and a sharing link to the notebook in your Drive. As detailed above, you should submit a 2-page report in PDF or DOCX format.
#
# **Learning Outcomes**
#
# This Assignment assesses the following module Learning Outcomes (from Definitive Module Document):
#
# * have knowledge of and understand how GPUs can accelerate data processing
# * be able to write data processing pipelines that exploit Tensorflow
# * have knowledge of and understand how to develop GPU-accelerated data processing pipelines using the Tensorflow and RAPIDS frameworks
#
# **Assignment Details**
#
# This assignment will test your ability to implement and test a deep neural network using keras. By varying the properties of the model and the data input pipeline, you will explore and analyse the training time and performance of the model. There will be four tasks for you to complete, each of which requires you to complete a range of tests on the model, visualise the results, and comment on them in a short report. Your report should focus on explaining and critically analysing the results—you will be assessed not just on your ability to show what is happening, but explain WHY it is happening.
#
# All coding work for this assignment should be done inside a copy of the Colab Notebook provided on this page. Any submissions not in this format will not be marked.
#
# **Task 1**: A model description is provided in the Colab Notebook for this assignment. Implement this model, ensuring that you have the correct output shapes for each of the layers and the correct number of model parameters. Train the model on the dataset provided in the notebook—initial training settings are provided also. Create plots of the losses and metrics of the training and validation data, and a plot that shows example images from each class that have been correctly AND incorrectly labelled by the model. Analyse these results in your report.
#
# **Task 2**: Select two additional optimizers. Including the one provided in the initial training settings, test your model with each of these optimizers using a range of different learning rates. You may need to train the model for more epochs to ensure that it converges on a solution. Create plots that show the losses and metrics for each of these runs, and comment on the results in your report. Select the optimizer and learning rate that provided the best results, and move onto the next task.
#
# **Task 3**: The batch size can heavily influence the amount of time it takes to train a model. Vary the batch size used to train the model and, utilising the Early Stopping callback provided, create plots that show how the time per epoch and total training time changes. Comment on these results in your report.
#
# **Task 4**: The model as provided does not contain any regularisation techniques. Edit the model architecture to include at least two examples of regularisation. Retrain the model using the new architecture, and repeat the analysis performed in task 1. In your report, compare and contrast the results from this task, with those from the initial model configuration.

# %%
# Module Imports - Add any additional modules here
import tensorflow as tf
import numpy as np
import time 
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, optimizers, losses, callbacks,\
                             regularizers

# %%
# Loading the Dataset. Here we use the CIFAR-10 dataset of labelled images

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Rescale the pixel values
x_train = x_train/255.
x_test = x_test/255.

# List of label names
class_names = ['plane', 'car', 'bird', 'cat', 'deer',
               'canine', 'frog', 'horse', 'boat', 'truck']

# %% [markdown]
# # Task 1 - Initial Model
#
# Implement the model architecture detailed below, using the Keras Functional API, ensuring that you have the correct output shapes for each of the layers.
#
# Train the model on the CIFAR-10 dataset.
#
# Create plots of the losses and metrics of the training and validation data, and plots that show example test images from each class that have been correctly AND incorrectly labelled by the model.
#
# Analyse these results in your report.
#
# **Model Architecture**
#
# A summary of the model architecture is given here, which shows the layers of the model, the output shapes of those layers, and the activation functions used. You will need to work out the other settings used to produce the model, such as the kernal sizes, padding schemes, and stride lengths. You should ensure that the output shapes and total number of parameters in your model match the summary here.
#
# ```
# Model: "cifar_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Activation
# =================================================================
#  Input (InputLayer)          [(None, 32, 32, 3)]       None
#
#  conv_1 (Conv2D)             (None, 32, 32, 16)        ReLU
#
#  conv_2 (Conv2D)             (None, 32, 32, 16)        ReLU
#
#  pool_1 (MaxPooling2D)       (None, 16, 16, 16)        None
#
#  conv_3 (Conv2D)             (None, 16, 16, 32)        ReLU
#
#  conv_4 (Conv2D)             (None, 16, 16, 32)        ReLU
#
#  pool_2 (MaxPooling2D)       (None, 8, 8, 32)          None
#
#  conv_5 (Conv2D)             (None, 8, 8, 64)          ReLU
#
#  conv_6 (Conv2D)             (None, 8, 8, 64)          ReLU
#
#  pool_3 (MaxPooling2D)       (None, 4, 4, 64)          None
#
#  flat (Flatten)              (None, 1024)              None
#
#  fc_1 (Dense)                (None, 512)               ReLU
#
#  Output (Dense)              (None, 10)                SoftMax
#
# =================================================================
# Total params: 602,010
# Trainable params: 602,010
# Non-trainable params: 0
# _________________________________________________________________
# ```

# %%
### Create the model using the provided architecture

Inp = layers.Input((32,32,3), dtype='float32', name='Model_Input')
Conv_1 = layers.Conv2D(16, (3,3), activation='relu', padding='same', name='conv_1')(Inp)
Conv_2 = layers.Conv2D(16, (3,3), activation='relu', padding='same', name='conv_2')(Conv_1)
Pool_1 = layers.MaxPool2D(pool_size=(2,2),name='pool_1')(Conv_2)
Conv_3 = layers.Conv2D(32, (3,3), activation='relu', padding='same', name='conv_3')(Pool_1)
Conv_4 = layers.Conv2D(32, (3,3), activation='relu', padding='same', name='conv_4')(Conv_3)
Pool_2 = layers.MaxPool2D(pool_size=(2,2), name='pool_2')(Conv_4)
Conv_5 = layers.Conv2D(64, (3,3), activation='relu', padding='same', name='conv_5')(Pool_2)
Conv_6 = layers.Conv2D(64, (3,3), activation='relu', padding='same', name='conv_6')(Conv_5)
Pool_3 = layers.MaxPool2D(pool_size=(2,2),name='pool_3')(Conv_6)
Flat = layers.Flatten(name = 'flatten')(Pool_3)
Dense1 = layers.Dense(512, activation='relu', name='fc_1')(Flat)
Output = layers.Dense(10, name='Output', activation='softmax')(Dense1)

cifar_model = models.Model(inputs=Inp, outputs=Output)
cifar_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Model_Input (InputLayer)    [(None, 32, 32, 3)]       0
#
#  conv_1 (Conv2D)             (None, 32, 32, 16)        448
#
#  conv_2 (Conv2D)             (None, 32, 32, 16)        2320
#
#  pool_1 (MaxPooling2D)       (None, 16, 16, 16)        0
#
#  conv_3 (Conv2D)             (None, 16, 16, 32)        4640
#
#  conv_4 (Conv2D)             (None, 16, 16, 32)        9248
#
#  pool_2 (MaxPooling2D)       (None, 8, 8, 32)          0
#
#  conv_5 (Conv2D)             (None, 8, 8, 64)          18496
#
#  conv_6 (Conv2D)             (None, 8, 8, 64)          36928
#
#  pool_3 (MaxPooling2D)       (None, 4, 4, 64)          0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  fc_1 (Dense)                (None, 512)               524800
#
#  Output (Dense)              (None, 10)                5130
#
# =================================================================
# Total params: 602,010
# Trainable params: 602,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
### Compile the model using the SGC optimizer, with default learning rate,
### Sparse Categorical Crossentropy, and accuracy metric.

cifar_model.compile(optimizer= optimizers.SGD(), loss= losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])

# %%
### Train the model for 50 epochs, with a batch size of 128. Include the test
### data for model validation. Store the losses and metrics in a history object.
history = cifar_model.fit(x_train, y_train, epochs = 50, validation_data = (x_test, y_test), batch_size = 128)
print(history.history.keys)
# Out:
# Epoch 1/50
# 391/391 [==============================] - 13s 9ms/step - loss: 2.2670 - accuracy: 0.1411 - val_loss: 2.1533 - val_accuracy: 0.2431
# Epoch 2/50
# 391/391 [==============================] - 3s 9ms/step - loss: 2.0276 - accuracy: 0.2659 - val_loss: 1.9267 - val_accuracy: 0.2991
# Epoch 3/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.9069 - accuracy: 0.3133 - val_loss: 1.9677 - val_accuracy: 0.2881
# Epoch 4/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.7631 - accuracy: 0.3664 - val_loss: 1.6149 - val_accuracy: 0.4331
# Epoch 5/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.6290 - accuracy: 0.4167 - val_loss: 1.5451 - val_accuracy: 0.4451
# Epoch 6/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.5369 - accuracy: 0.4471 - val_loss: 1.4843 - val_accuracy: 0.4644
# Epoch 7/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.4730 - accuracy: 0.4703 - val_loss: 1.4609 - val_accuracy: 0.4704
# Epoch 8/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.4215 - accuracy: 0.4923 - val_loss: 1.4444 - val_accuracy: 0.4865
# Epoch 9/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.3797 - accuracy: 0.5095 - val_loss: 1.3805 - val_accuracy: 0.5100
# Epoch 10/50
# 391/391 [==============================] - 3s 9ms/step - loss: 1.3354 - accuracy: 0.5257 - val_loss: 1.4072 - val_accuracy: 0.4995
# Epoch 11/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.2997 - accuracy: 0.5403 - val_loss: 1.3134 - val_accuracy: 0.5270
# Epoch 12/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2620 - accuracy: 0.5533 - val_loss: 1.3406 - val_accuracy: 0.5144
# Epoch 13/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.2292 - accuracy: 0.5669 - val_loss: 1.3076 - val_accuracy: 0.5330
# Epoch 14/50
# 391/391 [==============================] - 3s 9ms/step - loss: 1.1957 - accuracy: 0.5797 - val_loss: 1.2085 - val_accuracy: 0.5696
# Epoch 15/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1668 - accuracy: 0.5898 - val_loss: 1.2226 - val_accuracy: 0.5628
# Epoch 16/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.1393 - accuracy: 0.5979 - val_loss: 1.2234 - val_accuracy: 0.5694
# Epoch 17/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.1076 - accuracy: 0.6097 - val_loss: 1.1777 - val_accuracy: 0.5838
# Epoch 18/50
# 391/391 [==============================] - 3s 9ms/step - loss: 1.0784 - accuracy: 0.6208 - val_loss: 1.2172 - val_accuracy: 0.5690
# Epoch 19/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0544 - accuracy: 0.6287 - val_loss: 1.1406 - val_accuracy: 0.5978
# Epoch 20/50
# 391/391 [==============================] - 3s 7ms/step - loss: 1.0299 - accuracy: 0.6356 - val_loss: 1.1364 - val_accuracy: 0.6011
# Epoch 21/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.0063 - accuracy: 0.6474 - val_loss: 1.1439 - val_accuracy: 0.5982
# Epoch 22/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.9806 - accuracy: 0.6559 - val_loss: 1.1582 - val_accuracy: 0.5964
# Epoch 23/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.
50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.3008 - accuracy: 0.8946 - val_loss: 1.6292 - val_accuracy: 0.6188
# <built-in method keys of dict object at 0x7f470bd392c0>

# %%
### Create plots of the losses and metrics of the training and validation data,
### and plots that shows example test images from each class that have been
### correctly AND incorrectly labelled by the model.
plt.figure()
plt.plot(history.history['loss'], label='Training')
plt.plot(history.history['val_loss'], label='Validation')
plt.legend(loc=0)
plt.title('Model Loss')

plt.figure()
plt.plot(history.history['accuracy'], label='Training')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.legend(loc=0)
plt.title('Model Accuracy')

plt.show()

y_pred = cifar_model.predict(x_test)
y_pred_label = np.argmax(y_pred, axis=1)

f, ax = plt.subplots(5,5, figsize=(10, 12))
ax = ax.flatten()

for i in range(25):
    ax[i].imshow(x_test[i])
    ax[i].set_title(f'Truth = {y_test[i]}\nPred = {class_names[y_pred_label[i]]}')
    ax[i].set_xticks([])
    ax[i].set_yticks([])

plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# # Task 2 - Testing Optimizers
#
# Select two additional optimizers. Including the SGD algorithm already used, test all three of these optimizers with a range of different learning rates.
#
# You may need to train the model for more or less epochs to ensure that it converges on a solution.
#
# Create plots that show the losses and metrics for each of these runs, and comment on the results in your report.
#
# Select the optimizer and learning rate that provided the best results, and move onto the next task.
#
# **Note**: You should reset the weights of the model between each test. A function is provided to perform this task. Store the losses and metrics of each run under a different variable name, so that they can all be plotted together.

# %%
# Utility function that resets the weights of your model. Call this before
# recompiling your model with updated settings, to ensure you train the model
# from scratch.

def reinitialize(model):
    # Loop over the layers of the model
    for l in model.layers:
        # Check if the layer has initializers
        if hasattr(l,"kernel_initializer"):
            # Reset the kernel weights
            l.kernel.assign(l.kernel_initializer(tf.shape(l.kernel)))
        if hasattr(l,"bias_initializer"):
            # Reset the bias
            l.bias.assign(l.bias_initializer(tf.shape(l.bias)))

# Function modified from here: https://stackoverflow.com/questions/63435679/reset-all-weights-of-keras-model
reinitialize(cifar_model)
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(

# %%
### Test the SGD Optimizer, plus two others of your choice, with a range of
### learning rates.
cifar_model.compile(optimizer = optimizers.SGD(learning_rate = (0.1)),
                    loss= losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])
history = cifar_model.fit(x_train, y_train, epochs= 50, validation_data= (x_test, y_test), batch_size = 128)
print(history.history.keys)
reinitialize(cifar_model)

cifar_model.compile(optimizer = optimizers.Adam(learning_rate = (0.01)),  
                    loss= losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])
history1 = cifar_model.fit(x_train, y_train, epochs= 50, validation_data= (x_test, y_test), batch_size = 128)
print(history1.history.keys)
reinitialize(cifar_model)

cifar_model.compile(optimizer = optimizers.Adagrad(learning_rate = (0.001)), 
                    loss= losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])
history2 = cifar_model.fit(x_train, y_train, epochs= 50, validation_data= (x_test, y_test), batch_size = 128)
print(history2.history.keys)
reinitialize(cifar_model)
# Out:
# Epoch 1/50
# 391/391 [==============================] - 6s 12ms/step - loss: 2.2555 - accuracy: 0.1506 - val_loss: 2.3044 - val_accuracy: 0.0997
# Epoch 2/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.0681 - accuracy: 0.2409 - val_loss: 1.7714 - val_accuracy: 0.3605
# Epoch 3/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1
50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0791 - accuracy: 0.9736 - val_loss: 2.4342 - val_accuracy: 0.6395
# Epoch 34/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0858 - accuracy: 0.9724 - val_loss: 2.8891 - val_accuracy: 0.6176
# Epoch 35/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0742 - accuracy: 0.9764 - val_loss: 2.9714 - val_accuracy: 0.6172
# Epoch 36/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0959 - accuracy: 0.9710 - val_loss: 2.5459 - val_accuracy: 0.6281
# Epoch 37/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0581 - accuracy: 0.9814 - val_loss: 2.6286 - val_accuracy: 0.6402
# Epoch 38/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0645 - accuracy: 0.9793 - val_loss: 2.8651 - val_accuracy: 0.6323
# Epoch 39/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0757 - accuracy: 0.9763 - val_loss: 2.5395 - val_accuracy: 0.6190
# Epoch 40/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0484 - accuracy: 0.9844 - val_loss: 2.8949 - val_accuracy: 0.6418
# Epoch 41/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.1819 - accuracy: 0.9486 - val_loss: 2.3124 - val_accuracy: 0.6315
# Epoch 42/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0735 - accuracy: 0.9767 - val_loss: 2.6465 - val_accuracy: 0.6304
# Epoch 43/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0422 - accuracy: 0.9861 - val_loss: 2.7740 - val_accuracy: 0.6398
# Epoch 44/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0570 - accuracy: 0.9841 - val_loss: 2.8153 - val_accuracy: 0.6390
# Epoch 45/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0416 - accuracy: 0.9868 - val_loss: 3.1854 - val_accuracy: 0.6301
# Epoch 46/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0387 - accuracy: 0.9871 - val_loss: 3.1616 - val_accuracy: 0.6272
# Epoch 47/50
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0552 - accuracy: 0.9816 - val_loss: 2.9430 - val_accuracy: 0.6409
# Epoch 48/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0595 - accuracy: 0.9803 - val_loss: 2.9827 - val_accuracy: 0.6360
# Epoch 49/50
# 391/391 [==============================] - 3s 8ms/step - loss: 0.0762 - accuracy: 0.9763 - val_loss: 3.1030 - val_accuracy: 0.6398
# Epoch 50/50
# 391/391 [==============================] - 3s 9ms/step - loss: 0.0487 - accuracy: 0.9845 - val_loss: 3.3156 - val_accuracy: 0.6447
# <built-in method keys of dict object at 0x7f463074c640>
# Epoch 1/50
# 391/391 [==============================] - 7s 10ms/step - loss: 2.3082 - accuracy: 0.1004 - val_loss: 2.3035 - val_accuracy: 0.1000
# Epoch 2/50
# 391/391 [==============================] - 3s 9ms/step - loss: 2.3033 - accuracy: 0.0987 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 3/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3031 - accuracy: 0.0987 - val_loss: 2.3030 - val_accuracy: 0.1000
# Epoch 4/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3033 - accuracy: 0.0978 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 5/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.3032 - accuracy: 0.0991 - val_loss: 2.3033 - val_accuracy: 0.1000
# Epoch 6/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3034 - accuracy: 0.0995 - val_loss: 2.3032 - val_accuracy: 0.1000
# Epoch 7/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.3033 - accuracy: 0.0989 - val_loss: 2.3036 - val_accuracy: 0.1000
# Epoch 8/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3033 - accuracy: 0.0996 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 9/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3034 - accuracy: 0.0993 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 10/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3033 - accuracy: 0.0981 - val_loss: 2.3033 - val_accuracy: 0.1000
# Epoch 11/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3034 - accuracy: 0.1016 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 12/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3033 - accuracy: 0.1000 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 13/50
# 391/391 [==============================] - 3s 9ms/step - loss: 2.3033 - accuracy: 0.0990 - val_loss: 2.3033 - val_accuracy: 0.1000
# Epoch 14/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3034 - accuracy: 0.0977 - val_loss: 2.3030 - val_accuracy: 0.1000
# Epoch 15/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3033 - accuracy: 0.0976 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 16/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3033 - accuracy: 0.1006 - val_loss: 2.3035 - val_accuracy: 0.1000
# Epoch 17/50
# 391/391 [==============================] - 3s 9ms/step - loss: 2.3034 - accuracy: 0.1008 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 18/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3032 - accuracy: 0.0993 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 19/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3033 - accuracy: 0.0968 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 20/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3032 - accuracy: 0.1010 - val_loss: 2.3033 - val_accuracy: 0.1000
# Epoch 21/50
# 391/391 [==============================] - 3s 9ms/step - loss: 2.3033 - accuracy: 0.0982 - val_loss: 2.3030 - val_accuracy: 0.1000
# Epoch 22/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3034 - accuracy: 0.0981 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 23/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3031 - accuracy: 0.1002 - val_loss: 2.3032 - val_accuracy: 0.1000
# Epoch 24/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.3032 - accuracy: 0.0989 - val_loss: 2.3032 - val_accuracy: 0.1000
# Epoch 25/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3034 - accuracy: 0.0996 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 26/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3031 - accuracy: 0.0988 - val_loss: 2.3032 - val_accuracy: 0.1000
# Epoch 27/50
# 391/391 [==============================] - 3s 7ms/step - loss: 2.3034 - accuracy: 0.1007 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 28/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3033 - accuracy: 0.0983 - val_loss: 2.3038 - val_accuracy: 0.1000
# Epoch 29/50
# 391/391 [==============================] - 3s 9ms/step - loss: 2.3032 - accuracy: 0.0999 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 30/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3033 - accuracy: 0.1008 - val_loss: 2.3032 - val_accuracy: 0.1000
# Epoch 31/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3035 - accuracy: 0.0983 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 32/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3033 - accuracy: 0.0996 - val_loss: 2.3036 - val_accuracy: 0.1000
# Epoch 33/50
# 391/391 [==============================] - 3s 9ms/step - loss: 2.3034 - accuracy: 0.0988 - val_loss: 2.3033 - val_accuracy: 0.1000
# Epoch 34/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3032 - accuracy: 0.1003 - val_loss: 2.3032 - val_accuracy: 0.1000
# Epoch 35/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3034 - accuracy: 0.0984 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 36/50
# 391/391 [==============================] - 3s 9ms/step - loss: 2.3032 - accuracy: 0.0997 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 37/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3032 - accuracy: 0.1002 - val_loss: 2.3040 - val_accuracy: 0.1000
# Epoch 38/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3033 - accuracy: 0.0994 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 39/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3034 - accuracy: 0.0988 - val_loss: 2.3030 - val_accuracy: 0.1000
# Epoch 40/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3033 - accuracy: 0.0973 - val_loss: 2.3030 - val_accuracy: 0.1000
# Epoch 41/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3032 - accuracy: 0.0998 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 42/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3034 - accuracy: 0.0977 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 43/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3034 - accuracy: 0.0997 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 44/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3034 - accuracy: 0.0993 - val_loss: 2.3032 - val_accuracy: 0.1000
# Epoch 45/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3032 - accuracy: 0.1009 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 46/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3033 - accuracy: 0.0983 - val_loss: 2.3030 - val_accuracy: 0.1000
# Epoch 47/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3033 - accuracy: 0.0992 - val_loss: 2.3031 - val_accuracy: 0.1000
# Epoch 48/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.3034 - accuracy: 0.0985 - val_loss: 2.3030 - val_accuracy: 0.1000
# Epoch 49/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3034 - accuracy: 0.1019 - val_loss: 2.3039 - val_accuracy: 0.1000
# Epoch 50/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.3033 - accuracy: 0.0990 - val_loss: 2.3031 - val_accuracy: 0.1000
# <built-in method keys of dict object at 0x7f46304f5e40>
# Epoch 1/50
# 391/391 [==============================] - 6s 10ms/step - loss: 2.2987 - accuracy: 0.1013 - val_loss: 2.2933 - val_accuracy: 0.1141
# Epoch 2/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2837 - accuracy: 0.1399 - val_loss: 2.2700 - val_accuracy: 0.1372
# Epoch 3/50
# 391/391 [==============================] - 3s 8ms/step - loss: 2.2416 - accuracy: 0.1463 - val_loss: 2.1978 - val_accuracy: 0.1974
# Epoch 4/50
# 391/391 [==============================] - 3s 9ms/step - loss: 2.1010 - accuracy: 0.2432 - val_loss: 2.0034 - val_accuracy: 0.2731
# Epoch 5/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.9817 - accuracy: 0.2862 - val_loss: 1.9516 - val_accuracy: 0.3019
# Epoch 6/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.9410 - accuracy: 0.3018 - val_loss: 1.9155 - val_accuracy: 0.3232
# Epoch 7/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.9020 - accuracy: 0.3196 - val_loss: 1.8762 - val_accuracy: 0.3247
# Epoch 8/50
# 391/391 [==============================] - 3s 9ms/step - loss: 1.8626 - accuracy: 0.3357 - val_loss: 1.8381 - val_accuracy: 0.3429
# Epoch 9/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.8223 - accuracy: 0.3542 - val_loss: 1.8052 - val_accuracy: 0.3589
# Epoch 10/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.7801 - accuracy: 0.3702 - val_loss: 1.7618 - val_accuracy: 0.3765
# Epoch 11/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.7386 - accuracy: 0.3838 - val_loss: 1.7252 - val_accuracy: 0.3848
# Epoch 12/50
# 391/391 [==============================] - 3s 9ms/step - loss: 1.7021 - accuracy: 0.3949 - val_loss: 1.6871 - val_accuracy: 0.3991
# Epoch 13/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.6694 - accuracy: 0.4046 - val_loss: 1.6730 - val_accuracy: 0.4054
# Epoch 14/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.6411 - accuracy: 0.4159 - val_loss: 1.6256 - val_accuracy: 0.4260
# Epoch 15/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1
50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3592 - accuracy: 0.5191 - val_loss: 1.3773 - val_accuracy: 0.5109
# Epoch 45/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3556 - accuracy: 0.5217 - val_loss: 1.3689 - val_accuracy: 0.5146
# Epoch 46/50
# 391/391 [==============================] - 3s 9ms/step - loss: 1.3511 - accuracy: 0.5217 - val_loss: 1.3716 - val_accuracy: 0.5188
# Epoch 47/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3474 - accuracy: 0.5238 - val_loss: 1.3592 - val_accuracy: 0.5224
# Epoch 48/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3427 - accuracy: 0.5252 - val_loss: 1.3614 - val_accuracy: 0.5180
# Epoch 49/50
# 391/391 [==============================] - 3s 8ms/step - loss: 1.3391 - accuracy: 0.5259 - val_loss: 1.3619 - val_accuracy: 0.5188
# Epoch 50/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.3361 - accuracy: 0.5263 - val_loss: 1.3513 - val_accuracy: 0.5234
# <built-in method keys of dict object at 0x7f4630238500>

# %%
### Create plots that show the losses and metrics for each of these runs, and
### comment on the results in your report.
plt.figure()
plt.plot(history.history['loss'], label='Training')
plt.plot(history.history['val_loss'], label='Validation')
plt.legend(loc=0)
plt.title('Model Loss')

plt.figure()
plt.plot(history.history['accuracy'], label='Training')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.legend(loc=0)
plt.title('Model Accuracy')

plt.show()


plt.figure()
plt.plot(history1.history['loss'], label='Training')
plt.plot(history1.history['val_loss'], label='Validation')
plt.legend(loc=0)
plt.title('Model Loss')

plt.figure()
plt.plot(history1.history['accuracy'], label='Training')
plt.plot(history1.history['val_accuracy'], label='Validation')
plt.legend(loc=0)
plt.title('Model Accuracy')

plt.show()

plt.figure()
plt.plot(history2.history['loss'], label='Training')
plt.plot(history2.history['val_loss'], label='Validation')
plt.legend(loc=0)
plt.title('Model Loss')

plt.figure()
plt.plot(history2.history['accuracy'], label='Training')
plt.plot(history2.history['val_accuracy'], label='Validation')
plt.legend(loc=0)
plt.title('Model Accuracy')

plt.show()

# %% [markdown]
# # Task 3 - Testing Batch Sizes
#
# The batch size can heavily influence the amount of time it takes to train a model. Vary the batch size used to train the model and, utilising the Early Stopping callback provided, create plots that show how the time per epoch and total training time changes.
#
# Comment on these results in your report—consider both how the batch size influences the number of epochs it takes to reach a solution, and how long each epoch takes to run. Why is this the case?

# %%
### Train the model with a range of different batch sizes, resetting the weights
### each time. Use an Early Stopping callback to prevent the model training for
### too long.

Early_Stop = callbacks.EarlyStopping(monitor='val_loss', patience=3)

batch_sizes = [32, 64, 128, 256]
time_per_epoch = []
total_training_time = []
for batch_size in batch_sizes:
    print(f"Training model with batch size {batch_size}")
    reinitialize(cifar_model)
    start_time = time.time()
    cifar_model.compile(optimizer=optimizers.SGD(learning_rate=0.01),
                    loss=losses.SparseCategoricalCrossentropy(),
                    metrics=['accuracy'])    
    # Fit the model with early stopping
    history = cifar_model.fit(x_train, y_train, batch_size=batch_size, epochs=50, validation_split=0.2, callbacks=[Early_Stop])
    end_time = time.time()
    time_per_epoch.append((end_time - start_time) / len(history.history["loss"]))
    total_training_time.append(end_time - start_time)
    
    print("Time per epoch:", time_per_epoch[-1])
    print("Total training time:", total_training_time[-1])
    # Evaluate the model on the test set
    test_loss, test_acc = cifar_model.evaluate(x_test, y_test)
    print(f"Test accuracy with batch size {batch_size}: {test_acc}")
# Out:
# Training model with batch size 32
# /usr/local/lib/python3.9/dist-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Epoch 1
# Epoch 16/50
# 157/157 [==============================] - 2s 13ms/step - loss: 1.4625 - accuracy: 0.4781 - val_loss: 1.5593 - val_accuracy: 0.4438
# Epoch 17/50
# 157/157 [==============================] - 2s 13ms/step - loss: 1.4330 - accuracy: 0.4866 - val_loss: 1.5198 - val_accuracy: 0.4480
# Epoch 18/50
# 157/157 [==============================] - 2s 15ms/step - loss: 1.4173 - accuracy: 0.4948 - val_loss: 1.4684 - val_accuracy: 0.4792
# Epoch 19/50
# 157/157 [==============================] - 2s 13ms/step - loss: 1.3960 - accuracy: 0.5044 - val_loss: 1.4870 - val_accuracy: 0.4725
# Epoch 20/50
# 157/157 [==============================] - 2s 13ms/step - loss: 1.3784 - accuracy: 0.5107 - val_loss: 1.4415 - val_accuracy: 0.4883
# Epoch 21/50
# 157/157 [==============================] - 2s 13ms/step - loss: 1.3566 - accuracy: 0.5200 - val_loss: 1.4585 - val_accuracy: 0.4792
# Epoch 22/50
# 157/157 [==============================] - 2s 13ms/step - loss: 1.3432 - accuracy: 0.5250 - val_loss: 1.4360 - val_accuracy: 0.4830
# Epoch 23/50
# 157/157 [==============================] - 2s 14ms/step - loss: 1.3201 - accuracy: 0.5329 - val_loss: 1.3928 - val_accuracy: 0.5106
# Epoch 24/50
# 157/157 [==============================] - 2s 13ms/step - loss: 1.3060 - accuracy: 0.5390 - val_loss: 1.3383 - val_accuracy: 0.5294
# Epoch 25/50
# 157/157 [==============================] - 2s 13ms/step - loss: 1.2899 - accuracy: 0.5435 - val_loss: 1.4027 - val_accuracy: 0.5084
# Epoch 26/50
# 157/157 [==============================] - 2s 13ms/step - loss: 1.2715 - accuracy: 0.5502 - val_loss: 1.4175 - val_accuracy: 0.5083
# Epoch 27/50
# 157/157 [==============================] - 2s 13ms/step - loss: 1.2555 - accuracy: 0.5573 - val_loss: 1.3594 - val_accuracy: 0.5203
# Time per epoch: 2.1848118128599943
# Total training time: 58.98991894721985
# 313/313 [==============================] - 1s 3ms/step - loss: 1.3511 - accuracy: 0.5188
# Test accuracy with batch size 256: 0.5188000202178955

# %% [markdown]
# # Task 4 - Adding Regularisation
#
# The model as provided does not contain any regularisation techniques. Edit the model architecture to include at least two examples of regularisation. Retrain the model using the new architecture, and repeat the analysis performed in task 1.
#
# In your report, compare and contrast the results from this task, with those from the initial model configuration. Explain HOW and WHY the results are different, with consideration to the predicted classifications, losses and metrics.

# %%
### Update the model architecture to include at least two types of regularization.
### Train the model using the ideal settings found in previous tasks.
from tensorflow.keras import layers, models, regularizers

input_shape = (32, 32, 3)

# Define input layer
input_layer = layers.Input(shape=input_shape, name='input')

# Convolutional layer 1
conv_1 = layers.Conv2D(16, (3,3), activation='relu', padding='same', name='conv_1')(input_layer)
conv_2 = layers.Conv2D(16, (3,3), activation='relu', padding='same', name='conv_2')(conv_1)
pool_1 = layers.MaxPool2D(pool_size=(2,2), name='pool_1')(conv_2)
drop_1 = layers.Dropout(0.25)(pool_1) # Add dropout regularization

# Convolutional layer 2
conv_3 = layers.Conv2D(32, (3,3), activation='relu', padding='same', name='conv_3')(drop_1)
conv_4 = layers.Conv2D(32, (3,3), activation='relu', padding='same', name='conv_4')(conv_3)
pool_2 = layers.MaxPool2D(pool_size=(2,2), name='pool_2')(conv_4)
drop_2 = layers.Dropout(0.25)(pool_2) # Add dropout regularization

# Convolutional layer 3
conv_5 = layers.Conv2D(64, (3,3), activation='relu', padding='same', name='conv_5')(drop_2)
conv_6 = layers.Conv2D(64, (3,3), activation='relu', padding='same', name='conv_6')(conv_5)
pool_3 = layers.MaxPool2D(pool_size=(2,2), name='pool_3')(conv_6)
drop_3 = layers.Dropout(0.25)(pool_3) # Add dropout regularization

# Flatten and fully connected layer
flatten = layers.Flatten(name='flatten')(drop_3)
fc_1 = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01), name='fc_1')(flatten) # Add L2 regularization
drop_4 = layers.Dropout(0.5)(fc_1) # Add dropout regularization
output_layer = layers.Dense(10, activation='softmax', name='output')(drop_4)

# Define model
cifar_model = models.Model(inputs=input_layer, outputs=output_layer, name='cifar_model')
cifar_model.summary()

cifar_model.compile(optimizer=optimizers.SGD(),
                    loss=losses.SparseCategoricalCrossentropy(),
                    metrics=['accuracy'])

history = cifar_model.fit(x=x_train, y=y_train, epochs=50,
                          validation_data=(x_test, y_test),
                          batch_size=128)
print(history.history.keys)
# Out:
# Model: "cifar_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 32, 32, 3)]       0
#
#  conv_1 (Conv2D)             (None, 32, 32, 16)        448
#
#  conv_2 (Conv2D)             (None, 32, 32, 16)        2320
#
#  pool_1 (MaxPooling2D)       (None, 16, 16, 16)        0
#
#  dropout (Dropout)           (None, 16, 16, 16)        0
#
#  conv_3 (Conv2D)             (None, 16, 16, 32)        4640
#
#  conv_4 (Conv2D)             (None, 16, 16, 32)        9248
#
#  pool_2 (MaxPooling2D)       (None, 8, 8, 32)          0
#
#  dropout_1 (Dropout)         (None, 8, 8, 32)          0
#
#  conv_5 (Conv2D)             (None, 8, 8, 64)          18496
#
#  conv_6 (Conv2D)             (None, 8, 8, 64)          36928
#
#  pool_3 (MaxPooling2D)       (None, 4, 4, 64)          0
#
#  dropout_2 (Dropout)         (None, 4, 4, 64)          0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  fc_1 (Dense)                (None, 512)               524800
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  output (Dense)              (None, 10)                5130
#
# =================================================================
# Total params: 602,010
# Trainable params: 602,010
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 391/391 [==============================] - 6s 12ms/step - loss: 8.6230 - accuracy: 0.1116 - val_loss: 8.1330 - val_accuracy: 0.1933
# Epoch 2/50
# 391/391 [==============================] - 4s 10ms/step - loss: 7.6592 - accuracy: 0.1562 - val_loss: 7.1090 - val_accuracy: 0.2267
# Epoch 3/50
# 391/391 [==============================] - 4s 10ms/step - loss: 6.7193 - accuracy: 0.2135 - val_loss: 6.2619 - val_accuracy: 0.2885
# Epoch 4/50
# 391/391 [==============================] - 4s 10ms/step - loss: 5.9678 - accuracy: 0.2529 - val_loss: 5.6451 - val_accuracy: 0.2832
# Epoch 5/50
# 391/391 [==============================] - 4s 10ms/step - loss: 5.3248 - accuracy: 0.2837 - val_loss: 4.9622 - val_accuracy: 0.3479
# Epoch 6/50
# 391/391 [==============================] - 4s 9ms/step - loss: 4.7735 - accuracy: 0.3070 - val_loss: 4.4698 - val_accuracy: 0.3386
# Epoch 7/50
# 391/391 [==============================] - 4s 9ms/step - loss: 4.2861 - accuracy: 0.3369 - val_loss: 4.0329 - val_accuracy: 0.3608
# Epoch 8/50
# 391/391 [==============================] - 4s 10ms/step - loss: 3.8817 - accuracy: 0.3537 - val_loss: 3.6811 - val_accuracy: 0.3707
# Epoch 9/50
# 391/391 [==============================] - 4s 10ms/step - loss: 3.5293 - accuracy: 0.3715 - val_loss: 3.2712 - val_accuracy: 0.4196
# Epoch 10/50
# 391/391 [==============================] - 4s 9ms/step - loss: 3.2309 - accuracy: 0.3863 - val_loss: 2.9951 - val_accuracy: 0.4315
# Epoch 11/50
# 391/391 [==============================] - 4s 10ms/step - loss: 2.9730 - accuracy: 0.4017 - val_loss: 2.7897 - val_accuracy: 0.4313
# Epoch 12/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.7496 - accuracy: 0.4115 - val_loss: 2.5797 - val_accuracy: 0.4452
# Epoch 13/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.5603 - accuracy: 0.4240 - val_loss: 2.4123 - val_accuracy: 0.4529
# Epoch 14/50
# 391/391 [==============================] - 4s 11ms/step - loss: 2.3906 - accuracy: 0.4364 - val_loss: 2.2438 - val_accuracy: 0.4638
# Epoch 15/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.2464 - accuracy: 0.4460 - val_loss: 2.0961 - val_accuracy: 0.4904
# Epoch 16/50
# 391/391 [==============================] - 4s 9ms/step - loss: 2.1213 - accuracy: 0.4563 - val_loss: 1.9989 - val_accuracy: 0.4925
# Epoch 17/50
# 391/391 [==============================] - 4s 10ms/step - loss: 2.0128 - accuracy: 0.4616 - val_loss: 1.9567 - val_accuracy: 0.4788
# Epoch 18/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.9122 - accuracy: 0.4743 - val_loss: 1.7678 - val_accuracy: 0.5256
# Epoch 19/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.8243 - accuracy: 0.4866 - val_loss: 1.6997 - val_accuracy: 0.5338
# Epoch 20/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.7499 - accuracy: 0.4941 - val_loss: 1.6554 - val_accuracy: 0.5226
# Epoch 21/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.6829 - accuracy: 0.5056 - val_loss: 1.5803 - val_accuracy: 0.5382
# Epoch 22/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.6206 - accuracy: 0.5137 - val_loss: 1.5410 - val_accuracy: 0.5412
# Epoch 23/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.5699 - accuracy: 0.5220 - val_loss: 1.4396 - val_accuracy: 0.5660
# Epoch 24/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.5190 - accuracy: 0.5318 - val_loss: 1.4073 - val_accuracy: 0.5691
# Epoch 25/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.4747 - accuracy: 0.5395 - val_loss: 1.3462 - val_accuracy: 0.5856
# Epoch 26/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.4346 - accuracy: 0.5484 - val_loss: 1.3320 - val_accuracy: 0.5900
# Epoch 27/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.4006 - accuracy: 0.5538 - val_loss: 1.3078 - val_accuracy: 0.5943
# Epoch 28/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.3667 - accuracy: 0.5641 - val_loss: 1.2588 - val_accuracy: 0.6065
# Epoch 29/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.3375 - accuracy: 0.5725 - val_loss: 1.2362 - val_accuracy: 0.6054
# Epoch 30/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.3065 - accuracy: 0.5796 - val_loss: 1.2514 - val_accuracy: 0.6014
# Epoch 31/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.2788 - accuracy: 0.5873 - val_loss: 1.2359 - val_accuracy: 0.6032
# Epoch 32/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.2578 - accuracy: 0.5925 - val_loss: 1.1548 - val_accuracy: 0.6358
# Epoch 33/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.2399 - accuracy: 0.5964 - val_loss: 1.1317 - val_accuracy: 0.6406
# Epoch 34/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.2209 - accuracy: 0.6029 - val_loss: 1.1406 - val_accuracy: 0.6293
# Epoch 35/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.1992 - accuracy: 0.6099 - val_loss: 1.1652 - val_accuracy: 0.6259
# Epoch 36/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.1824 - accuracy: 0.6164 - val_loss: 1.0905 - val_accuracy: 0.6506
# Epoch 37/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.1684 - accuracy: 0.6189 - val_loss: 1.0698 - val_accuracy: 0.6533
# Epoch 38/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.1550 - accuracy: 0.6243 - val_loss: 1.1057 - val_accuracy: 0.6441
# Epoch 39/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.1422 - accuracy: 0.6307 - val_loss: 1.0674 - val_accuracy: 0.6568
# Epoch 40/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.1309 - accuracy: 0.6366 - val_loss: 1.0497 - val_accuracy: 0.6614
# Epoch 41/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.1194 - accuracy: 0.6408 - val_loss: 1.0657 - val_accuracy: 0.6608
# Epoch 42/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.1069 - accuracy: 0.6459 - val_loss: 1.0525 - val_accuracy: 0.6658
# Epoch 43/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.0990 - accuracy: 0.6465 - val_loss: 0.9985 - val_accuracy: 0.6872
# Epoch 44/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.0874 - accuracy: 0.6511 - val_loss: 1.0083 - val_accuracy: 0.6791
# Epoch 45/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.0804 - accuracy: 0.6568 - val_loss: 1.0213 - val_accuracy: 0.6748
# Epoch 46/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.0704 - accuracy: 0.6607 - val_loss: 1.0094 - val_accuracy: 0.6822
# Epoch 47/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.0657 - accuracy: 0.6631 - val_loss: 1.0485 - val_accuracy: 0.6678
# Epoch 48/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.0549 - accuracy: 0.6665 - val_loss: 0.9976 - val_accuracy: 0.6830
# Epoch 49/50
# 391/391 [==============================] - 4s 9ms/step - loss: 1.0469 - accuracy: 0.6703 - val_loss: 1.0041 - val_accuracy: 0.6890
# Epoch 50/50
# 391/391 [==============================] - 4s 10ms/step - loss: 1.0441 - accuracy: 0.6730 - val_loss: 0.9930 - val_accuracy: 0.6840
# <built-in method keys of dict object at 0x7f46fb8ccd00>

# %%
### Repeat your analysis from task 1, creating plots of the losses, metrics AND
### predicted classifications of images in the test set.


plt.figure()
plt.plot(history.history['loss'], label='Training')
plt.plot(history.history['val_loss'], label='Validation')
plt.legend(loc=0)
plt.title('Model Loss')

plt.figure()
plt.plot(history.history['accuracy'], label='Training')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.legend(loc=0)
plt.title('Model Accuracy')

plt.show()

y_pred = cifar_model.predict(x_test)
y_pred_label = np.argmax(y_pred, axis=1)

f, ax = plt.subplots(5,5, figsize=(10, 12))
ax = ax.flatten()

for i in range(25):
    ax[i].imshow(x_test[i])
    ax[i].set_title(f'Truth = {class_names[y_test[i][0]]}\nPred = {class_names[y_pred_label[i]]}')
    ax[i].set_xticks([])
    ax[i].set_yticks([])

plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step
